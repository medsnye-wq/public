# %%
[03:37, 14/03/2026] Souniye Mohamdi: import json
import pandas as pd

with open(r"C:\Users\PRIMO TEK\anaconda3\envs\Tp!_Kdd\Data\TP1.json", "r") as f:
    json_data = json.load(f)

df_json = pd.DataFrame(json_data["students"])
df_json["source"] = "JSON"

print("JSON chargé:", df_json.shape)
df_json.head()
[03:37, 14/03/2026] Souniye Mohamdi: import sqlite3
import pandas as pd

# إنشاء الملف students.db تلقائياً
conn = sqlite3.connect(r"C:\Users\PRIMO TEK\anaconda3\envs\Tp!_Kdd\Data\students.db")
cursor = conn.cursor()

# إنشاء الجدول + إدخال البيانات
cursor.execute("""
CREATE TABLE IF NOT EXISTS grades (
    id INTEGER PRIMARY KEY,
    name TEXT,
    score REAL
)
""")

cursor.executemany("INSERT INTO grades (name, score) VALUES (?, ?)", [
    ("Ali",    15.5),
    ("Fatima", 18.0),
    ("Omar",   12.0),
])
conn.commit()
print("la base de données est prête ‘´)[03:37, 14/03/2026] Souniye Mohamdi: import json
import pandas as pd

with open(r"C:\Users\PRIMO TEK\anaconda3\envs\Tp!_Kdd\Data\TP1.json", "r") as f:
    json_data = json.load(f)

df_json = pd.DataFrame(json_data["students"])
df_json["source"] = "JSON"

print("JSON chargé:", df_json.shape)
df_json.head()
[03:37, 14/03/2026] Souniye Mohamdi: import sqlite3
import pandas as pd

# إنشاء الملف students.db تلقائياً
conn = sqlite3.connect(r"C:\Users\PRIMO TEK\anaconda3\envs\Tp!_Kdd\Data\students.db")
cursor = conn.cursor()

# إنشاء الجدول + إدخال البيانات
cursor.execute("""
CREATE TABLE IF NOT EXISTS grades (
    id INTEGER PRIMARY KEY,
    name TEXT,
    score REAL
)
""")

cursor.executemany("INSERT INTO grades (name, score) VALUES (?, ?)", [
    ("Ali",    15.5),
    ("Fatima", 18.0),
    ("Omar",   12.0),
])
conn.commit()
print("la base de données est prête ‘´)[03:37, 14/03/2026] Souniye Mohamdi: import json
import pandas as pd

with open(r"C:\Users\PRIMO TEK\anaconda3\envs\Tp!_Kdd\Data\TP1.json", "r") as f:
    json_data = json.load(f)

df_json = pd.DataFrame(json_data["students"])
df_json["source"] = "JSON"

print("JSON chargé:", df_json.shape)
df_json.head()
[03:37, 14/03/2026] Souniye Mohamdi: import sqlite3
import pandas as pd

# إنشاء الملف students.db تلقائياً
conn = sqlite3.connect(r"C:\Users\PRIMO TEK\anaconda3\envs\Tp!_Kdd\Data\students.db")
cursor = conn.cursor()

# إنشاء الجدول + إدخال البيانات
cursor.execute("""
CREATE TABLE IF NOT EXISTS grades (
    id INTEGER PRIMARY KEY,
    name TEXT,
    score REAL
)
""")

cursor.executemany("INSERT INTO grades (name, score) VALUES (?, ?)", [
    ("Ali",    15.5),
    ("Fatima", 18.0),
    ("Omar",   12.0),
])
conn.commit()
print("la base de données est prête ‘´)

# %%
import json
import pandas as pd

with open(r"C:\Users\PRIMO TEK\anaconda3\envs\Tp!_Kdd\Data\TP1.json", "r") as f:
    json_data = json.load(f)

df_json = pd.DataFrame(json_data["students"])
df_json["source"] = "JSON"

print("JSON chargé:", df_json.shape)
df_json.head() 
import sqlite3
import pandas as pd

# إنشاء الملف students.db تلقائياً
conn = sqlite3.connect(C:/Users/MTP MEDIA/Documents/ANACONDA/python.exe" "c:/Users/MTP MEDIA/Desktop/projet Data_mining/tp.py")
cursor = conn.cursor()

# إنشاء الجدول + إدخال البيانات
cursor.execute("""
CREATE TABLE IF NOT EXISTS grades (
    id INTEGER PRIMARY KEY,
    name TEXT,
    score REAL
)
""")

cursor.executemany("INSERT INTO grades (name, score) VALUES (?, ?)", [
    ("Ali",    15.5),
    ("Fatima", 18.0),
    ("Omar",   12.0),
])
conn.commit()
print("la base de données est prête ‘´)
